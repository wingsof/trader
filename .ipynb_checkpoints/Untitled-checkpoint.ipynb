# %%
from morning.pipeline.chooser.cybos.db.kosdaq_search_bull_chooser import KosdaqSearchBullChooser

# %%
from datetime import date

# %%
ksbc = KosdaqSearchBullChooser(date(2018, 1, 2))
# Out:
# 2018-01-02
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A214450_D 1
# INSERT A214680_D 1
# INSERT A214870_D 1
# INSERT A215000_D 1
# INSERT A215090_D 1
# INSERT A215100_D 1
# INSERT A215200_D 1
# INSERT A215360_D 1
# INSERT A215380_D 1
# INSERT A215480_D 1
# INSERT A215600_D 1
# INSERT A215790_D 1
# INSERT A216050_D 1
# INSERT A217190_D 1
# INSERT A217270_D 1
# INSERT A217480_D 1
# INSERT A217500_D 1
# INSERT A217600_D 1
# INSERT A217620_D 1
# INSERT A217730_D 1
# INSERT A217820_D 1
# INSERT A218150_D 1
# INSERT A218410_D 1
# INSERT A219130_D 1
# INSERT A219420_D 1
# INSERT A219550_D 1
# INSERT A219750_D 1
# INSERT A220100_D 1
# INSERT A220180_D 1
# INSERT A220260_D 1
# INSERT A220630_D 1
# INSERT A221610_D 1
# INSERT A221840_D 1
# INSERT A221980_D 1
# INSERT A222040_D 1
# INSERT A222080_D 1
# INSERT A222110_D 1
# INSERT A222420_D 1
# INSERT A222800_D 1
# INSERT A222810_D 1
# INSERT A222980_D 1
# INSERT A223310_D 1
# INSERT A224060_D 1
# INSERT A224110_D 1
# INSERT A225190_D 1
# INSERT A225330_D 1
# INSERT A225430_D 1
# INSERT A225530_D 1
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A225570_D 1
# INSERT A225590_D 1
# INSERT A226340_D 1
# INSERT A226350_D 1
# INSERT A226360_D 1
# INSERT A226400_D 1
# INSERT A226440_D 1
# INSERT A227610_D 1
# INSERT A227950_D 1
# INSERT A228340_D 1
# INSERT A228760_D 1
# INSERT A228850_D 1
# INSERT A230240_D 1
# INSERT A230360_D 1
# INSERT A230980_D 1
# INSERT A232140_D 1
# INSERT A234100_D 1
# INSERT A234300_D 1
# INSERT A234920_D 1
# INSERT A236200_D 1
# INSERT A237690_D 1
# INSERT A237750_D 1
# INSERT A237880_D 1
# INSERT A238090_D 1
# INSERT A238120_D 1
# INSERT A238490_D 1
# INSERT A239340_D 1
# INSERT A239610_D 1
# INSERT A240810_D 1
# INSERT A241520_D 1
# INSERT A241690_D 1
# INSERT A241710_D 1
# INSERT A241770_D 1
# INSERT A241790_D 1
# INSERT A241820_D 1
# INSERT A242040_D 1
# INSERT A243070_D 1
# INSERT A243840_D 1
# INSERT A246690_D 1
# INSERT A246720_D 1
# INSERT A250000_D 1
# INSERT A250060_D 1
# INSERT A250930_D 1
# INSERT A251370_D 1
# INSERT A251630_D 1
# INSERT A252500_D 1
# INSERT A253450_D 1
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A253840_D 1
# INSERT A254120_D 1
# INSERT A255440_D 1
# INSERT A256630_D 1
# INSERT A256840_D 1
# INSERT A256940_D 1
# INSERT A258610_D 1
# INSERT A258790_D 1
# INSERT A259630_D 1
# INSERT A260930_D 1
# INSERT A261200_D 1
# INSERT A263540_D 1
# INSERT A263600_D 1
# INSERT A263720_D 1
# INSERT A263750_D 1
# INSERT A263770_D 1
# INSERT A263800_D 1
# INSERT A263810_D 1
# INSERT A263860_D 1
# INSERT A263920_D 1
# INSERT A264290_D 1
# INSERT A264450_D 1
# INSERT A264850_D 1
# INSERT A265480_D 1
# INSERT A265520_D 1
# INSERT A265560_D 1
# INSERT A265920_D 1
# INSERT A267320_D 1
# INSERT A267980_D 1
# INSERT A269620_D 1
# INSERT A270520_D 1
# INSERT A271740_D 1
# INSERT A272290_D 1
# INSERT A273060_D 1
# INSERT A276920_D 1
# INSERT A277410_D 1
# INSERT A277480_D 1
# INSERT A279410_D 1
# INSERT A279600_D 1
# INSERT A281410_D 1
# INSERT A281740_D 1
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A900040_D 1
# INSERT A900070_D 1
# INSERT A900080_D 1
# INSERT A900100_D 1
# INSERT A900110_D 1
# INSERT A900120_D 1
# INSERT A900250_D 1
# INSERT A900260_D 1
# INSERT A900270_D 1
# INSERT A900280_D 1
# INSERT A900290_D 1
# INSERT A900300_D 1
# INSERT A900310_D 1
# INSERT A950110_D 1
# INSERT A950130_D 1
# INSERT A950140_D 1
# INSERT A950160_D 1

# %%
import numpy as np

a = np.array([])
b = []
def hello():
    for i in range(100000):
        a = np.append(a, [i])
        
def hello2():
    for i in range(100000):
        b.append(i)
        
def hello3():
    for i in range(100000):
        a = np.concatenate((a, [[i]]), axis=0)

# %%
# %timeit hello
# Out:
# 27.7 ns ± 0.995 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit hello2
# Out:
# 26.9 ns ± 1.31 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit hello3
# Out:
# 31.8 ns ± 0.289 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
a = np.append(a, [0, 1, 2, 3, 4 ,5])
#a.min()
a.mean()
# Out:
# 2.5

# %%
from pymongo import MongoClient
import pandas as pd

db = MongoClient('mongodb://192.168.0.22:27017')
with db:
    stock_db = db['stock']
    collections = stock_db.collection_names()
    for c in collections:
        if c.endswith('_M_M'):
            #stock_db[c].drop()
            #db[c].drop()
            """
            df = pd.DataFrame(list(stock_db[c].find()))
            a = len(df)
            df.drop_duplicates(subset='0', keep='first', inplace=True)
            print(df['0'])
            b = len(df)
            if a != b:
                print(a, b)
            """
            print(c)
# Out:
# c:\users\nnnli\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   import sys

# %%
def hello(a: str):
    return len(a)

# %%
hello(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1f805eb1b77d> in <module>
# ----> 1 hello(1)
#
# <ipython-input-32-a48d72756638> in hello(a)
#       1 def hello(a: str):
# ----> 2     return len(a)
#
# TypeError: object of type 'int' has no len()

# %%
from scipy.signal import find_peaks, peak_prominences
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
plt.rcParams['figure.figsize'] = [15, 20]
import gc
import numpy as np
from morning.pipeline.stream.cybos.stock.db.min_excel_tick import MinExcelTick
from morning.pipeline.converter.cybos.stock.day_tick import StockDayTickConverter
import pandas as pd
from datetime import date
from morning.pipeline.stream.cybos.stock.db.min_tick import MinTick
from morning.pipeline.chooser.cybos.db.kosdaq_all_chooser import KosdaqAllChooser
from morning.pipeline.chooser.cybos.db.kosdaq_bull_chooser import KosdaqBullChooser
from morning.back_data.fetch_stock_data import get_day_minute_period_data
from morning.back_data.holidays import is_holidays
from morning.pipeline.chooser.cybos.db.kosdaq_search_bull_chooser import KosdaqSearchBullChooser

from datetime import timedelta, datetime

# %%
from datetime import date
from pymongo import MongoClient
from morning.back_data.holidays import is_holidays
from morning.config import db
from morning.back_data.fetch_stock_data import get_day_period_data, get_day_minute_period_data

remote_codes = []
stock = MongoClient(db.HOME_MONGO_ADDRESS)['stock']
codes = list(stock['KOSDAQ_CODES'].find())
for code in codes:
    remote_codes.append(code['code'])

for code in remote_codes:
    print(code)
    get_day_period_data(code, date(2018, 1, 1), date(2019, 12, 7))
    #get_day_minute_period_data(code, date(2018, 1, 1), date(2019, 12, 7))
# Out:
# A000250
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A000250_D 2
# INSERT A000250_D 6
# INSERT A000250_D 2
# INSERT A000250_D 310
# INSERT A000250_M 1407
# INSERT A000250_M 754
# INSERT A000250_M 12151
# INSERT A000250_M 4281
# INSERT A000250_M 373
# INSERT A000250_M 1140
# INSERT A000250_M 9105
# INSERT A000250_M 1129
# INSERT A000250_M 2187
# INSERT A000250_M 6846
# INSERT A000250_M 10081
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A000250_M 105386
# A000440
# INSERT A000440_D 2
# INSERT A000440_D 6
# INSERT A000440_D 2
# INSERT A000440_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A000440_M 42968
# A001000
# INSERT A001000_D 2
# INSERT A001000_D 6
# INSERT A001000_D 2
# INSERT A001000_D 310
# INSERT A001000_M 625
# INSERT A001000_M 6255
# INSERT A001000_M 20276
# INSERT A001000_M 371
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A001000_M 65452
# A001540
# INSERT A001540_D 2
# INSERT A001540_D 6
# INSERT A001540_D 2
# INSERT A001540_D 310
# INSERT A001540_M 1506
# INSERT A001540_M 9763
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A001540_M 75186
# A001810
# INSERT A001810_D 2
# INSERT A001810_D 6
# INSERT A001810_D 2
# INSERT A001810_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A001810_M 51873
# A001840
# INSERT A001840_D 2
# INSERT A001840_D 6
# INSERT A001840_D 2
# INSERT A001840_D 310
# INSERT A001840_M 6312
# INSERT A001840_M 7953
# INSERT A001840_M 3205
# INSERT A001840_M 3149
# INSERT A001840_M 761
# INSERT A001840_M 4848
# INSERT A001840_M 355
# INSERT A001840_M 1805
# INSERT A001840_M 13314
# INSERT A001840_M 2854
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A001840_M 79967
# A002230
# INSERT A002230_D 2
# INSERT A002230_D 6
# INSERT A002230_D 2
# INSERT A002230_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A002230_M 82334
# A002290
# INSERT A002290_D 2
# INSERT A002290_D 6
# INSERT A002290_D 2
# INSERT A002290_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A002290_M 67477
# A002680
# INSERT A002680_D 2
# INSERT A002680_D 6
# INSERT A002680_D 2
# INSERT A002680_D 310
# INSERT A002680_M 27287
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A002680_M 43697
# A002800
# INSERT A002800_D 2
# INSERT A002800_D 6
# INSERT A002800_D 2
# INSERT A002800_D 310
# INSERT A002800_M 2377
# INSERT A002800_M 4281
# INSERT A002800_M 7497
# INSERT A002800_M 6718
# INSERT A002800_M 21601
# INSERT A002800_M 1130
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A002800_M 74001
# A003100
# INSERT A003100_D 2
# INSERT A003100_D 6
# INSERT A003100_D 2
# INSERT A003100_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A003100_M 36543
# A003310
# INSERT A003310_D 2
# INSERT A003310_D 6
# INSERT A003310_D 2
# INSERT A003310_D 310
# INSERT A003310_M 6128
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A003310_M 103593
# A003380
# INSERT A003380_D 2
# INSERT A003380_D 6
# INSERT A003380_D 2
# INSERT A003380_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A003380_M 151678
# A003800
# INSERT A003800_D 2
# INSERT A003800_D 6
# INSERT A003800_D 2
# INSERT A003800_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A003800_M 27019
# A004590
# INSERT A004590_D 2
# INSERT A004590_D 6
# INSERT A004590_D 2
# INSERT A004590_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A004590_M 32455
# A004650
# INSERT A004650_D 2
# INSERT A004650_D 6
# INSERT A004650_D 2
# INSERT A004650_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A004650_M 73812
# A004780
# INSERT A004780_D 2
# INSERT A004780_D 6
# INSERT A004780_D 2
# INSERT A004780_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A004780_M 62154
# A005160
# INSERT A005160_D 2
# INSERT A005160_D 6
# INSERT A005160_D 2
# INSERT A005160_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005160_M 85391
# A005290
# INSERT A005290_D 2
# INSERT A005290_D 6
# INSERT A005290_D 2
# INSERT A005290_D 310
# INSERT A005290_M 2189
# INSERT A005290_M 1427
# INSERT A005290_M 11590
# INSERT A005290_M 6420
# INSERT A005290_M 381
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005290_M 9343
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005290_M 125699
# A005670
# INSERT A005670_D 2
# INSERT A005670_D 6
# INSERT A005670_D 2
# INSERT A005670_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005670_M 69517
# A005710
# INSERT A005710_D 2
# INSERT A005710_D 6
# INSERT A005710_D 2
# INSERT A005710_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005710_M 54020
# A005860
# INSERT A005860_D 2
# INSERT A005860_D 6
# INSERT A005860_D 2
# INSERT A005860_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005860_M 14863
# INSERT A005860_M 17861
# INSERT A005860_M 8885
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005860_M 83185
# A005990
# INSERT A005990_D 2
# INSERT A005990_D 6
# INSERT A005990_D 2
# INSERT A005990_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A005990_M 88829
# A006050
# INSERT A006050_D 2
# INSERT A006050_D 6
# INSERT A006050_D 2
# INSERT A006050_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006050_M 45845
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006050_M 74165
# A006140
# INSERT A006140_D 2
# INSERT A006140_D 6
# INSERT A006140_D 2
# INSERT A006140_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006140_M 29852
# A006580
# INSERT A006580_D 2
# INSERT A006580_D 6
# INSERT A006580_D 2
# INSERT A006580_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006580_M 81957
# A006620
# INSERT A006620_D 6
# INSERT A006620_D 2
# INSERT A006620_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006620_M 13434
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006620_M 96660
# A006730
# INSERT A006730_D 2
# INSERT A006730_D 6
# INSERT A006730_D 2
# INSERT A006730_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006730_M 152920
# A006910
# INSERT A006910_D 2
# INSERT A006910_D 6
# INSERT A006910_D 2
# INSERT A006910_D 310
# INSERT A006910_M 2050
# Request Limit is reached
# INSERT A006910_M 3622
# INSERT A006910_M 19922
# INSERT A006910_M 4281
# INSERT A006910_M 1118
# INSERT A006910_M 735
# INSERT A006910_M 15568
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006910_M 83527
# A006920
# INSERT A006920_D 2
# INSERT A006920_D 6
# INSERT A006920_D 2
# INSERT A006920_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006920_M 5513
# INSERT A006920_M 7931
# INSERT A006920_M 7917
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A006920_M 80552
# A007330
# INSERT A007330_D 2
# INSERT A007330_D 6
# INSERT A007330_D 2
# INSERT A007330_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007330_M 40100
# A007370
# INSERT A007370_D 2
# INSERT A007370_D 6
# INSERT A007370_D 2
# INSERT A007370_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007370_M 17683
# INSERT A007370_M 1742
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007370_M 51755
# A007390
# INSERT A007390_D 2
# INSERT A007390_D 6
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007390_D 2
# INSERT A007390_D 310
# INSERT A007390_M 381
# INSERT A007390_M 381
# INSERT A007390_M 1427
# INSERT A007390_M 7328
# INSERT A007390_M 16937
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007390_M 126363
# A007530
# INSERT A007530_D 2
# INSERT A007530_D 6
# INSERT A007530_D 2
# Request Limit is reached
# INSERT A007530_D 310
# INSERT A007530_M 1948
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007530_M 60970
# A007680
# INSERT A007680_D 2
# INSERT A007680_D 6
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007680_D 2
# INSERT A007680_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007680_M 92009
# A007720
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007720_D 2
# INSERT A007720_D 6
# INSERT A007720_D 2
# INSERT A007720_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007720_M 133773
# A007770
# INSERT A007770_D 2
# INSERT A007770_D 6
# INSERT A007770_D 2
# INSERT A007770_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007770_M 46134
# A007820
# INSERT A007820_D 2
# INSERT A007820_D 6
# INSERT A007820_D 2
# INSERT A007820_D 310
# INSERT A007820_M 3224
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A007820_M 137127
# A008290
# INSERT A008290_D 2
# INSERT A008290_D 6
# INSERT A008290_D 2
# INSERT A008290_D 310
# INSERT A008290_M 3818
# INSERT A008290_M 11581
# INSERT A008290_M 377
# INSERT A008290_M 1139
# INSERT A008290_M 1427
# INSERT A008290_M 6431
# INSERT A008290_M 361
# INSERT A008290_M 3049
# INSERT A008290_M 11490
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A008290_M 72361
# A008370
# INSERT A008370_D 2
# INSERT A008370_D 6
# INSERT A008370_D 2
# INSERT A008370_D 310
# INSERT A008370_M 11546
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A008370_M 35442
# A008470
# INSERT A008470_D 2
# INSERT A008470_D 6
# INSERT A008470_D 2
# INSERT A008470_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A008470_M 68506
# A008800
# INSERT A008800_D 2
# INSERT A008800_D 6
# INSERT A008800_D 2
# INSERT A008800_D 310
# INSERT A008800_M 14969
# INSERT A008800_M 2806
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A008800_M 45221
# A008830
# INSERT A008830_D 2
# INSERT A008830_D 6
# INSERT A008830_D 2
# INSERT A008830_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A008830_M 18193
# A009300
# INSERT A009300_D 2
# INSERT A009300_D 6
# INSERT A009300_D 2
# INSERT A009300_D 310
# INSERT A009300_M 14681
# INSERT A009300_M 16534
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A009300_M 35162
# A009520
# INSERT A009520_D 2
# INSERT A009520_D 6
# INSERT A009520_D 2
# INSERT A009520_D 310
# INSERT A009520_M 26734
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A009520_M 123634
# A009620
# INSERT A009620_D 2
# INSERT A009620_D 6
# INSERT A009620_D 2
# INSERT A009620_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A009620_M 72908
# A009730
# INSERT A009730_D 2
# INSERT A009730_D 6
# INSERT A009730_D 2
# INSERT A009730_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A009730_M 120836
# A009780
# INSERT A009780_D 2
# INSERT A009780_D 6
# INSERT A009780_D 2
# INSERT A009780_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A009780_M 49613
# A010170
# INSERT A010170_D 2
# INSERT A010170_D 6
# INSERT A010170_D 2
# INSERT A010170_D 310
# INSERT A010170_M 1427
# INSERT A010170_M 7598
# INSERT A010170_M 2563
# INSERT A010170_M 7135
# INSERT A010170_M 1427
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A010170_M 29496
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A010170_M 105251
# A010240
# INSERT A010240_D 2
# INSERT A010240_D 6
# INSERT A010240_D 2
# INSERT A010240_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A010240_M 114516
# A010280
# INSERT A010280_D 2
# INSERT A010280_D 6
# INSERT A010280_D 2
# INSERT A010280_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A010280_M 78926
# A010470
# INSERT A010470_D 2
# INSERT A010470_D 6
# INSERT A010470_D 2
# INSERT A010470_D 310
# INSERT A010470_M 10028
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A010470_M 55718
# A011040
# INSERT A011040_D 2
# INSERT A011040_D 6
# INSERT A011040_D 2
# INSERT A011040_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011040_M 95214
# A011080
# INSERT A011080_D 2
# INSERT A011080_D 6
# INSERT A011080_D 2
# INSERT A011080_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011080_M 56652
# A011320
# INSERT A011320_D 2
# INSERT A011320_D 6
# INSERT A011320_D 2
# INSERT A011320_D 310
# INSERT A011320_M 361
# INSERT A011320_M 378
# INSERT A011320_M 742
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011320_M 27689
# INSERT A011320_M 11939
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011320_M 97787
# A011370
# INSERT A011370_D 2
# INSERT A011370_D 6
# INSERT A011370_D 2
# INSERT A011370_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011370_M 129445
# A011560
# INSERT A011560_D 2
# INSERT A011560_D 6
# INSERT A011560_D 2
# INSERT A011560_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A011560_M 97977
# A012340
# INSERT A012340_D 2
# INSERT A012340_D 6
# INSERT A012340_D 2
# INSERT A012340_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012340_M 95513
# A012620
# INSERT A012620_D 2
# INSERT A012620_D 6
# INSERT A012620_D 2
# INSERT A012620_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012620_M 27412
# A012700
# INSERT A012700_D 2
# INSERT A012700_D 6
# INSERT A012700_D 2
# INSERT A012700_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012700_M 88028
# A012790
# INSERT A012790_D 2
# INSERT A012790_D 6
# INSERT A012790_D 2
# INSERT A012790_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012790_M 66714
# A012860
# INSERT A012860_D 2
# INSERT A012860_D 6
# INSERT A012860_D 2
# INSERT A012860_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012860_M 6504
# INSERT A012860_M 15449
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A012860_M 61330
# A013030
# INSERT A013030_D 2
# INSERT A013030_D 6
# INSERT A013030_D 2
# INSERT A013030_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013030_M 120447
# A013120
# INSERT A013120_D 2
# INSERT A013120_D 6
# INSERT A013120_D 2
# INSERT A013120_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013120_M 138751
# A013310
# INSERT A013310_D 2
# INSERT A013310_D 6
# INSERT A013310_D 2
# INSERT A013310_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013310_M 120244
# A013720
# INSERT A013720_D 2
# INSERT A013720_D 6
# INSERT A013720_D 2
# INSERT A013720_D 310
# INSERT A013720_M 10394
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013720_M 56725
# A013810
# INSERT A013810_D 2
# INSERT A013810_D 6
# INSERT A013810_D 2
# INSERT A013810_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013810_M 110348
# A013990
# INSERT A013990_D 2
# INSERT A013990_D 6
# INSERT A013990_D 2
# INSERT A013990_D 310
# INSERT A013990_M 22331
# INSERT A013990_M 22285
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A013990_M 75643
# A014100
# INSERT A014100_D 2
# INSERT A014100_D 6
# INSERT A014100_D 2
# INSERT A014100_D 310
# INSERT A014100_M 3915
# INSERT A014100_M 9319
# INSERT A014100_M 6458
# INSERT A014100_M 957
# INSERT A014100_M 1083
# INSERT A014100_M 4480
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014100_M 82696
# A014190
# INSERT A014190_D 2
# INSERT A014190_D 6
# INSERT A014190_D 2
# INSERT A014190_D 310
# INSERT A014190_M 1078
# INSERT A014190_M 4879
# INSERT A014190_M 14981
# INSERT A014190_M 12439
# INSERT A014190_M 6509
# INSERT A014190_M 7448
# INSERT A014190_M 695
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014190_M 85333
# A014200
# INSERT A014200_D 2
# INSERT A014200_D 6
# INSERT A014200_D 2
# INSERT A014200_D 310
# INSERT A014200_M 22653
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014200_M 95511
# A014470
# INSERT A014470_D 2
# INSERT A014470_D 6
# INSERT A014470_D 2
# INSERT A014470_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014470_M 109287
# A014570
# INSERT A014570_D 2
# INSERT A014570_D 6
# INSERT A014570_D 2
# INSERT A014570_D 310
# INSERT A014570_M 12975
# INSERT A014570_M 1771
# INSERT A014570_M 3145
# INSERT A014570_M 1119
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014570_M 20383
# INSERT A014570_M 1308
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014570_M 65811
# A014620
# INSERT A014620_D 2
# INSERT A014620_D 6
# INSERT A014620_D 2
# INSERT A014620_D 310
# INSERT A014620_M 12554
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014620_M 142291
# A014940
# INSERT A014940_D 2
# INSERT A014940_D 6
# INSERT A014940_D 2
# INSERT A014940_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014940_M 67853
# A014970
# INSERT A014970_D 2
# INSERT A014970_D 6
# INSERT A014970_D 2
# INSERT A014970_D 310
# INSERT A014970_M 7568
# INSERT A014970_M 344
# INSERT A014970_M 7709
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014970_M 8782
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A014970_M 76064
# A015710
# INSERT A015710_D 2
# INSERT A015710_D 6
# INSERT A015710_D 2
# INSERT A015710_D 310
# INSERT A015710_M 10038
# INSERT A015710_M 4812
# INSERT A015710_M 363
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A015710_M 10216
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A015710_M 62382
# A015750
# INSERT A015750_D 2
# INSERT A015750_D 6
# INSERT A015750_D 2
# INSERT A015750_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A015750_M 145997
# A016100
# INSERT A016100_D 2
# INSERT A016100_D 6
# INSERT A016100_D 2
# INSERT A016100_D 310
# INSERT A016100_M 4233
# INSERT A016100_M 11118
# INSERT A016100_M 3610
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016100_M 112920
# A016250
# INSERT A016250_D 2
# INSERT A016250_D 6
# INSERT A016250_D 2
# INSERT A016250_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016250_M 116560
# A016600
# INSERT A016600_D 2
# INSERT A016600_D 6
# INSERT A016600_D 2
# INSERT A016600_D 310
# INSERT A016600_M 581
# INSERT A016600_M 3413
# INSERT A016600_M 2553
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016600_M 98025
# A016670
# INSERT A016670_D 2
# INSERT A016670_D 6
# INSERT A016670_D 2
# INSERT A016670_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016670_M 119525
# A016790
# INSERT A016790_D 6
# INSERT A016790_D 2
# INSERT A016790_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016790_M 89601
# A016920
# INSERT A016920_D 2
# INSERT A016920_D 6
# INSERT A016920_D 2
# INSERT A016920_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A016920_M 74847
# A017000
# INSERT A017000_D 2
# INSERT A017000_D 6
# INSERT A017000_D 2
# INSERT A017000_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A017000_M 77056
# A017250
# INSERT A017250_D 2
# INSERT A017250_D 6
# INSERT A017250_D 2
# INSERT A017250_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# ...
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032680_M 91084
# A032685
# INSERT A032685_D 2
# INSERT A032685_D 6
# INSERT A032685_D 2
# INSERT A032685_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032685_M 28957
# A032750
# INSERT A032750_D 2
# INSERT A032750_D 6
# INSERT A032750_D 2
# INSERT A032750_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032750_M 79457
# A032790
# INSERT A032790_D 2
# INSERT A032790_D 6
# INSERT A032790_D 2
# INSERT A032790_D 310
# INSERT A032790_M 3026
# INSERT A032790_M 15471
# INSERT A032790_M 380
# INSERT A032790_M 1127
# INSERT A032790_M 361
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032790_M 2155
# INSERT A032790_M 7349
# INSERT A032790_M 12905
# INSERT A032790_M 1203
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032790_M 86125
# A032800
# INSERT A032800_D 2
# INSERT A032800_D 6
# INSERT A032800_D 2
# INSERT A032800_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032800_M 37980
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032800_M 76567
# A032820
# INSERT A032820_D 2
# INSERT A032820_D 6
# INSERT A032820_D 2
# INSERT A032820_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032820_M 20563
# INSERT A032820_M 2565
# INSERT A032820_M 4408
# INSERT A032820_M 2570
# INSERT A032820_M 10356
# INSERT A032820_M 5404
# INSERT A032820_M 3979
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032820_M 98663
# A032850
# INSERT A032850_D 2
# INSERT A032850_D 6
# INSERT A032850_D 2
# INSERT A032850_D 310
# INSERT A032850_M 3064
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032850_M 11344
# INSERT A032850_M 4022
# INSERT A032850_M 26511
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032850_M 65687
# A032860
# INSERT A032860_D 2
# INSERT A032860_D 6
# INSERT A032860_D 2
# INSERT A032860_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032860_M 106986
# A032940
# INSERT A032940_D 2
# INSERT A032940_D 6
# INSERT A032940_D 2
# INSERT A032940_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032940_M 113374
# A032960
# INSERT A032960_D 2
# INSERT A032960_D 6
# INSERT A032960_D 2
# INSERT A032960_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032960_M 36277
# A032980
# INSERT A032980_D 2
# INSERT A032980_D 6
# INSERT A032980_D 2
# INSERT A032980_D 310
# INSERT A032980_M 367
# INSERT A032980_M 359
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032980_M 1781
# INSERT A032980_M 14957
# INSERT A032980_M 1576
# INSERT A032980_M 10721
# INSERT A032980_M 367
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A032980_M 97202
# A033050
# INSERT A033050_D 2
# INSERT A033050_D 6
# INSERT A033050_D 2
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033050_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033050_M 65933
# A033100
# INSERT A033100_D 2
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033100_D 6
# INSERT A033100_D 2
# INSERT A033100_D 310
# INSERT A033100_M 14302
# INSERT A033100_M 2854
# INSERT A033100_M 381
# INSERT A033100_M 1135
# INSERT A033100_M 7315
# INSERT A033100_M 351
# INSERT A033100_M 356
# INSERT A033100_M 13562
# INSERT A033100_M 2854
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033100_M 82299
# A033110
# INSERT A033110_D 2
# INSERT A033110_D 6
# INSERT A033110_D 2
# INSERT A033110_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033110_M 3878
# INSERT A033110_M 16093
# INSERT A033110_M 1427
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033110_M 113207
# A033130
# INSERT A033130_D 2
# INSERT A033130_D 6
# INSERT A033130_D 2
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033130_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033130_M 102078
# A033160
# INSERT A033160_D 2
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033160_D 6
# INSERT A033160_D 2
# INSERT A033160_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033160_M 102851
# A033170
# INSERT A033170_D 2
# INSERT A033170_D 6
# INSERT A033170_D 2
# INSERT A033170_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033170_M 115896
# A033200
# INSERT A033200_D 2
# INSERT A033200_D 6
# INSERT A033200_D 2
# INSERT A033200_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033200_M 13722
# A033230
# INSERT A033230_D 2
# INSERT A033230_D 6
# INSERT A033230_D 2
# INSERT A033230_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033230_M 64797
# A033290
# INSERT A033290_D 2
# INSERT A033290_D 6
# INSERT A033290_D 2
# INSERT A033290_D 310
# INSERT A033290_M 4661
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033290_M 153558
# A033310
# INSERT A033310_D 2
# INSERT A033310_D 6
# INSERT A033310_D 2
# INSERT A033310_D 310
# INSERT A033310_M 1143
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033310_M 69744
# A033320
# INSERT A033320_D 2
# INSERT A033320_D 6
# INSERT A033320_D 2
# INSERT A033320_D 310
# INSERT A033320_M 1427
# INSERT A033320_M 28227
# INSERT A033320_M 1090
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033320_M 102799
# A033340
# INSERT A033340_D 2
# INSERT A033340_D 6
# INSERT A033340_D 2
# INSERT A033340_D 310
# INSERT A033340_M 313
# INSERT A033340_M 19755
# INSERT A033340_M 7326
# INSERT A033340_M 1139
# INSERT A033340_M 6818
# INSERT A033340_M 5695
# INSERT A033340_M 2549
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033340_M 103911
# A033430
# INSERT A033430_D 2
# INSERT A033430_D 6
# INSERT A033430_D 2
# INSERT A033430_D 310
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# INSERT A033430_M 89759
# A033500
# INSERT A033500_D 2
# INSERT A033500_D 6
# INSERT A033500_D 2
# INSERT A033500_D 310
# INSERT A033500_M 5316
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# Request Limit is reached
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3baaf7075b81> in <module>
#      14     print(code)
#      15     get_day_period_data(code, date(2018, 1, 1), date(2019, 12, 7))
# ---> 16     get_day_minute_period_data(code, date(2018, 1, 1), date(2019, 12, 7))
#
# C:\workspace\trader\morning\back_data\fetch_stock_data.py in get_day_minute_period_data(code, from_date, until_date)
#      67
#      68 def get_day_minute_period_data(code, from_date, until_date):
# ---> 69     return get_day_period_data(code, from_date, until_date, db_suffix='_M')
#      70
#      71
#
# C:\workspace\trader\morning\back_data\fetch_stock_data.py in get_day_period_data(code, from_date, until_date, db_suffix)
#      54     working_days = get_working_days(from_date, until_date)
#      55     #print('WORKING DAYS:', working_days)
# ---> 56     empties = _insert_day_data(stock_db, code, days, working_days, db_suffix)
#      57     if len(empties) > 0:
#      58         db_data = list(stock_db[code + db_suffix].find({'0': {'$gte':time_converter.datetime_to_intdate(from_date), '$lte': time_converter.datetime_to_intdate(until_date)}}))
#
# C:\workspace\trader\morning\back_data\fetch_stock_data.py in _insert_day_data(db, code, days, working_days, db_suffix)
#      31                 length, data = stock_chart.get_day_period_data(code, p[0], p[1])
#      32             elif db_suffix == '_M':
# ---> 33                 length, data = stock_chart.get_min_period_data(code, p[0], p[1])
#      34             if length > 0:
#      35                 print('INSERT', code + db_suffix, length)
#
# C:\workspace\trader\morning\cybos_api\stock_chart.py in get_min_period_data(code, startdate, enddate)
#      63     result = []
#      64     while enddate - pivot > timedelta(days=5):
# ---> 65         _, result[len(result):len(result)] = get_period_data_raw(code, pivot, pivot + timedelta(days=5))
#      66         pivot = pivot + timedelta(days=6)
#      67
#
# C:\workspace\trader\morning\cybos_api\stock_chart.py in get_period_data_raw(code, start_date, end_date, period_type)
#      43         d = {}
#      44         for j in range(len(data_list)):
# ---> 45             d[str(j)] = chart_obj.GetDataValue(j, i)
#      46         data.append(d)
#      47
#
# c:\users\nnnli\appdata\local\programs\python\python37-32\lib\site-packages\win32com\client\dynamic.py in GetDataValue(self, _MIDL__ISysDib0001_, _MIDL__ISysDib0002_)
#
# c:\users\nnnli\appdata\local\programs\python\python37-32\lib\site-packages\win32com\client\dynamic.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     285
#     286         def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
# --> 287                 result = self._oleobj_.InvokeTypes(*(dispid, LCID, wFlags, retType, argTypes) + args)
#     288                 return self._get_good_object_(result, user, resultCLSID)
#     289
#
# KeyboardInterrupt:
